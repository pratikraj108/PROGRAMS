# %%
import numpy as np
import matplotlib.pyplot as mtp
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 6, 8, 10])

x_mean = np.mean(x)
y_mean = np.mean(y)
A = x - x_mean
B= y - y_mean
C = A ** 2
m = np.sum(A * B) / np.sum(C)
c = y_mean - m * x_mean
print("Slope:", m)
print("Intercept:", c)

mtp.plot(x,y,color="red")
# Out:
# Slope: 2.0
# Intercept: 0.0

# %%
import matplotlib.pyplot as mtp
import pandas as pd
import sklearn.model_selection
import sklearn.metrics
import numpy as np

data_set = pd.read_csv('Salary2.csv')

x = data_set.iloc[:, :-1].values
y = data_set.iloc[:, 1].values

#Splitting the dataset into training and test sets
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.4, random_state = 1)

#fitting the simple Linear Regression model to the training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)

#prrediction of test and training set result
y_pred = regressor.predict(x_test)
x_pred = regressor.predict(x_train)

print(y_pred)
print(y_test)
# Out:
# [ 697067.34133073  852559.50059008 1000647.27131328 1296822.81275967
#   186164.5323357   208377.69794418 1089499.9337472   734089.28401153
#  1185756.98471727  756302.44962001  778515.61522849  963625.32863248
#   556383.95914369  882177.05473472  526766.40499905 1059882.37960256
#   911794.60887936  674854.17572225  586001.51328833  408296.1884205 ]
# [ 700000  820000 1020000 1300000  205000  245000 1050000  750000 1250000
#   720000  800000  920000  570000  900000  530000 1100000  870000  620000
#   540000  420000]

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test, y_pred.round())
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 28184.55

# %%
from sklearn.metrics import mean_absolute_percentage_error
maep=mean_absolute_percentage_error(y_test,y_pred.round())
print("Mean Absolute Percentage Error:", maep)
# Out:
# Mean Absolute Percentage Error: 0.04387125784673234

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,y_pred.round())
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 1095217280.85

# %%
rmse=np.sqrt(mse)

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
print(r2)
# Out:
# 0.9872039685916775

# %%
accuracy_percent = r2 * 100
print("Accuracy Percentage:", accuracy_percent)
# Out:
# Accuracy Percentage: 98.72039685916775

# %%
mtp.scatter(x_train, y_train, color="green")
mtp.plot(x_train, x_pred, color="red")
mtp.title("Salary vs Experience (Training Dataset)")
mtp.xlabel("Years of Experience")
mtp.ylabel("Salary(In Rupees)")
mtp.show()
x1 = [[2.6]]

y1= regressor.predict(x1)

print(y1)
# Out:
# [304634.74891426]

# %%
import sklearn.metrics as sm
print("Mean absolute error =", round(sm.mean_absolute_error(y_test, y_pred), 2))
print("Mean squared error =", round(sm.mean_squared_error(y_test, y_pred), 2))
print("Median absolute error =", round(sm.median_absolute_error(y_test, y_pred), 2))
print("Explain variance score =", round(sm.explained_variance_score(y_test, y_pred), 2))
print("R2 score =", round(sm.r2_score(y_test, y_pred), 2))
# Out:
# Mean absolute error = 28184.5
# Mean squared error = 1095215527.25
# Median absolute error = 27021.94
# Explain variance score = 0.99
# R2 score = 0.99
