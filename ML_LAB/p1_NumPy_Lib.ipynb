# %%
#NumPy Library
import numpy as np

a = [9,3,3,5]
print(np.array(a))  # Converting list into numpy array
# Out:
# [9 3 3 5]

# %%
z = np.zeros((2, 3))
print(z)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
o = np.ones((3, 2))
print(o)
# Out:
# [[1. 1.]
#  [1. 1.]
#  [1. 1.]]

# %%
r = np.arange(1, 10, 2)
print(r)
# Out:
# [1 3 5 7 9]

# %%
a = np.eye(3)
print(a)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
b = np.eye(2, 4)
print(b)
# Out:
# [[1. 0. 0. 0.]
#  [0. 1. 0. 0.]]

# %%
r = np.random.rand(5)
print(r)
# Out:
# [0.30511635 0.86871361 0.68561767 0.71476301 0.90717447]

# %%
r2 = np.random.rand(2, 3)
print(r2)
# Out:
# [[0.82731511 0.8135464  0.56042339]
#  [0.81038778 0.89345973 0.48711768]]

# %%
x = np.random.randint(1, 10)
print(x)
# Out:
# 6

# %%
arr = np.random.randint(10, 50, size=5)
print(arr)
# Out:
# [37 31 40 22 19]

# %%
mat = np.random.randint(1, 100, size=(2, 3))
print(mat)
# Out:
# [[ 5 43 34]
#  [ 6  6 30]]
